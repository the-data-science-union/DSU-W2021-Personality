# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/anishdulla/Desktop/YPA.csv')

# %%
df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
df.columns
# Out:
# Index(['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country',
#        'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock',
#        ...
#        'Age', 'Height', 'Weight', 'Number of siblings', 'Gender',
#        'Left - right handed', 'Education', 'Only child', 'Village - town',
#        'House - block of flats'],
#       dtype='object', length=150)

# %%
df1 = df[["Gender", "Education", "Spending on looks"]]

# %%
heatmap_data = pd.pivot_table(df1, values='Spending on looks', index=['Education'], columns='Gender')
sns.heatmap(heatmap_data)

# %%
df["Total_Phobia_Score"] = df["Flying"] + df["Storm"] + df["Darkness"] + df["Heights"] + df["Spiders"] + df["Snakes"] + df["Rats"] + df["Ageing"] + df["Dangerous dogs"] + df["Fear of public speaking"]

# %%
sns.catplot(data=df, x="Number of siblings", y="Total_Phobia_Score", kind = "boxen")

# %%
sns.catplot(y="Alcohol", x="Entertainment spending", kind="violin", hue = "Gender", data=df)
